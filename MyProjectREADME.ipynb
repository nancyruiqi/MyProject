# %% [markdown]
# My Project
# -----------
#
# This is the description of *My Project*.
# It is a project which is mine.
#
# So far I have:
#
# * made a README.md file
# * initialized git in this directory
# * added the README.md file to those being tracked
# * edited README.md

# %% [markdown]
# ### But, Jupyter has a richer *MarkDown* language, including $\LaTeX$, images, and more

# %% [markdown]
# For example,
#
# * you can have ***images***:
#
# ![gravwave](Figures/LIGO_measurement_of_gravitational_waves.svg.png)

# %% [markdown]
# * or ***math***:

# %% [markdown]
# ### Maxwell's Equations in 4-dimensional relativistic form:
#
# $~$
#
# $\displaystyle{
# \begin{align}
# \partial_\mu F_{\nu\rho} + \partial_\nu F_{\rho\mu} + \partial_\rho F_{\mu\nu} &= 0 \\
# \partial_\mu F^{\mu\nu} &= j^\nu
# \end{align}}
# $
#
# $~$
# where $F_{\mu\nu} = \partial_\mu A_\nu - \partial_\nu A_\mu$

# %% [markdown]
# * and ***code***:

# %%
import numpy as np

np.pi**2/6

# %% [markdown]
# $ \displaystyle{\sum_n \frac{1}{n^2} = \frac{\pi^2}{6}  }$

# %%
s = 0
for n in np.arange(1,10000):
    s += 1/n**2
    
s
# Out:
# 1.6448340618480652

# %%
# %matplotlib notebook

x = np.linspace(-10,10)
y = np.sin(x)

plt.plot(x,y, "b-")
# Out:
# <img src="data:image/png;base64,..." width="640">
